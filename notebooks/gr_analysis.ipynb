# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../survey/familarity_with_online/GR.csv")
df
# Out:
#      Response        Submitted on:           Institution        Department  \
# 0         287  14/07/2020 17:25:21                   NaN               NaN
# 1         616  23/07/2020 20:33:37                   NaN               NaN
# 2         346  16/07/2020 20:21:00                   NaN               NaN
# 3         629  24/07/2020 11:45:49                   NaN               NaN
# 4         388  17/07/2020 09:38:19                   NaN               NaN
# ..        ...                  ...                   ...               ...
# 103       334  16/07/2020 16:53:22                   NaN               NaN
# 104       604  21/07/2020 13:50:21                   NaN               NaN
# 105       515  17/07/2020 13:04:23  Kathmandu University  Computer Science
# 106       324  16/07/2020 16:04:03                   NaN               NaN
# 107       620  23/07/2020 23:13:50   Kathmandu Universty             DOCSE
#
# ...

# %%
def drop_columns_by_index(df, columns_to_drop):
    """
    Drop specified columns from a dataframe based on their index positions.

    Parameters:
    df (pandas.DataFrame): The dataframe from which to drop columns.
    columns_to_drop (list): A list of column index positions to drop.

    Returns:
    pandas.DataFrame: The dataframe with the specified columns dropped.
    """
    columns_to_keep = [col for col in df.columns if df.columns.get_loc(col) not in columns_to_drop]
    df_dropped = df[columns_to_keep]
    return df_dropped

# %%
df = drop_columns_by_index(df, [0, 1, 2, 3, 4, 5, 7, 8])
df
# Out:
#        ID  \
# 0     148
# 1     442
# 2     473
# 3     478
# 4     525
# ..    ...
# 103  2255
# 104  2256
# 105  2257
# 106  2258
# 107  2260
#
#      Q01->1: Strongly Disagree, 2: Moderately Disagree, 3: UNDECIDED, 4: Moderately Agree, 5: Strongly Agree  \
# 0                                                    4
# 1                                                    4
# 2                                                    3
# 3                                                    4
# 4                                                    3
# ..                                                 ...
# 103                                                  4
# 104                                                  5
# 105                                                  4
# 106                                                  4
# 107                                                  5
#
# ...

# %%
def truncate_column_titles(df, start_col=1):
    """
    Truncate the titles of columns in a dataframe to the first 6 characters, starting from a specified column.

    Parameters:
    df (pandas.DataFrame): The dataframe to modify.
    start_col (int): The index of the first column to modify. Default is 4.

    Returns:
    pandas.DataFrame: The dataframe with truncated column titles.
    """
    df_truncated = df.copy()
    df_truncated.columns = [col[:3] if i >= start_col else col for i, col in enumerate(df_truncated.columns)]
    return df_truncated

# %% [markdown]
# ## Questions
# Q1: I prefer to work by myself on assignments in my courses.<br>
# Q2: I often daydream during class.<br>
# Q3: Working with other students on class activities is something I enjoy doing.<br>
# Q4: I want teachers to state exactly what they expect from students.<br>
# Q5: To do well, it is necessary to compete with other students for the teacher's attention.<br>
# Q6: I do whatever is asked of me to learn the content in my classes.<br>
# Q7: My ideas about the content often are as good as those in the textbook.<br>
# Q8: Classroom activities are usually boring.<br>
# Q9: I enjoy discussing my ideas about course content with other students.<br>
# Q10: I rely on my teachers to tell me what is important for me to learn.<br>
# Q11: It is necessary to compete with other students to get a good grade.<br>
# Q12: Class sessions typically are worth attending.<br>
# Q13: I study what is important to me and not always what the instructor says is important.<br>
# Q14: Very seldom do i become excited about material covered in a course.<br>
# Q15: I enjoy hearing what other students think about issues raised in class.<br>
# Q16: I want clear and detailed instructions on how to complete assignments.<br>
# Q17: In class, I must compete with other students to get my ideas across.<br>
# Q18: I get more out of going to class than staying at home.<br>
# Q19: I learn a lot of the content in my classes on my own.<br>
# Q20: I don't want to attend most of my classes.<br>
# Q21: Students should be encouraged to share more of their ideas with each other.<br>
# Q22: I complete assignments exactly the way my teachers tell me to do them.<br>
# Q23: Students have to be aggressive to do well in courses.<br>
# Q24: It is my responsibility to get as much as I can out of a course.<br>
# Q25: I feel very confident about my ability to learn on my own.<br>
# Q26: Paying attention during class sessions is difficult for me to do.<br>
# Q27: I like to study for tests with other students.<br>
# Q28: Trying to decide what to study or how to do assignments makes me uncomfortable.<br>
# Q29: I like to solve problems or answer questions before anybody else can.<br>
# Q30: Classroom activities are interesting.<br>
# Q31: I like to develop my own ideas about course content.<br>
# Q32: I have given up trying to learn anything from going to class.<br>
# Q33: Class sessions make me feel like part of a team where people help each other learn.<br>
# Q34: Students should be more closely supervised by teachers on course projects.<br>
# Q35: To get ahead in class, it is necessary to step on the toes of other students.<br>
# Q36: I try to participate as much as I can in all aspects of a course.<br>
# Q37: I have my own ideas about how classes should be run.<br>
# Q38: I study just hard enough to get by.<br>
# Q39: An important part of taking courses is learning to get along with other people.<br>
# Q40: My notes contain almost everything the teacher said in class.<br>
# Q41: Being one of the best students in my classes is very important to me.<br>
# Q42: I do all course assignments well whether or not I think they are interesting.<br>
# Q43: If I like a topic, I try to find out more about it on my own.<br>
# Q44: I typically cram for exams.<br>
# Q45: Learning the material was a cooperative effort between students and teachers.<br>
# Q46: I prefer class sessions that are highly organized.<br>
# Q47: To stand out in my classes, I complete assignments better than other students.<br>
# Q48: I typically complete course assignments before their deadlines.<br>
# Q49: I prefer to work on class projects and assignments by myself.<br>
# Q50: I would prefer that teachers ignore me in class.<br>
# Q51: I am willing to help other students out when they do not understand something.<br>
# Q52: Students should be told exactly what material is to be covered on exams.<br>
# Q53: I like to know how well other students are doing on exams and course assignments.<br>
# Q54: I complete required assignments as well as those that are optional.<br>
# Q55: When I don't understand something, I first try to figure it out for myself.<br>
# Q56: During class sessions, I tend to socialize with people sitting next to me.<br>
# Q57: I enjoy participating in small group activities during class.<br>
# Q58: I want teachers to have outlines or notes on the board.<br>
# Q59: I want my teachers to give me more recognition for the good work I do.<br>
# Q60: In my classes, I often sit toward the front of the room.<br>

# %%
df = truncate_column_titles(df)
df
# Out:
#        ID  Q01  Q02  Q03  Q04  Q05  Q06  Q07  Q08  Q09  ...  Q51  Q52  Q53  \
# 0     148    4    3    5    5    2    4    3    4    4  ...    5    5    5
# 1     442    4    2    4    5    2    4    3    4    5  ...    5    3    4
# 2     473    3    4    5    4    2    3    4    3    4  ...    5    4    3
# 3     478    4    3    4    4    2    5    3    1    4  ...    4    5    4
# 4     525    3    1    4    4    2    3    2    2    4  ...    4    3    3
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 103  2255    4    2    4    5    1    4    3    3    4  ...    5    5    4
# 104  2256    5    1    5    4    2    5    4    1    5  ...    5    4    4
# 105  2257    4    2    4    5    3    4    3    3    4  ...    5    5    4
# 106  2258    4    3    3    4    2    4    2    3    2  ...    4    5    5
# 107  2260    5    2    4    4    1    3    5    2    5  ...    5    2    2
#
#      Q54  Q55  Q56  Q57  Q58  Q59  Q60
# ...

# %%
import pandas as pd
from sklearn.cluster import KMeans

# Assuming you have loaded your dataframe containing student responses
# Replace 'df' with the name of your dataframe

# Perform k-means clustering on the responses (excluding the first column 'ID')
X = df.iloc[:, 1:].values  # Extracting values from the dataframe

# Define the number of clusters
n_clusters = 5

# Instantiate the k-means model
kmeans = KMeans(n_clusters=n_clusters, random_state=42)

# Fit the model to the data
kmeans.fit(X)

# Get the cluster labels
cluster_labels = kmeans.labels_

# Add the 'Type' column to the dataframe indicating the cluster for each student
df['Type'] = cluster_labels

# Display the dataframe with the added 'Type' column
print(df)
# Out:
#        ID  Q01  Q02  Q03  Q04  Q05  Q06  Q07  Q08  Q09  ...  Q52  Q53  Q54  \
# 0     148    4    3    5    5    2    4    3    4    4  ...    5    5    3
# 1     442    4    2    4    5    2    4    3    4    5  ...    3    4    3
# 2     473    3    4    5    4    2    3    4    3    4  ...    4    3    3
# 3     478    4    3    4    4    2    5    3    1    4  ...    5    4    4
# 4     525    3    1    4    4    2    3    2    2    4  ...    3    3    4
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 103  2255    4    2    4    5    1    4    3    3    4  ...    5    4    4
# 104  2256    5    1    5    4    2    5    4    1    5  ...    4    4    5
# 105  2257    4    2    4    5    3    4    3    3    4  ...    5    4    5
# 106  2258    4    3    3    4    2    4    2    3    2  ...    5    5    3
# 107  2260    5    2    4    4    1    3    5    2    5  ...    2    2    4
#
#      Q55  Q56  Q57  Q58  Q59  Q60  Type
# ...

# %%
# Define names for the cluster types
cluster_names = {
    0: "Engaged Learners",
    1: "Moderately Engaged Learners",
    2: "Disengaged Learners",
    3: "Competitive Learners",
    4: "Undecided Learners"
}

# Map cluster labels to cluster names
df['Type'] = df['Type'].map(cluster_names)

# Display the dataframe with the updated 'Type' column
print(df)
# Out:
#        ID  Q01  Q02  Q03  Q04  Q05  Q06  Q07  Q08  Q09  ...  Q52  Q53  Q54  \
# 0     148    4    3    5    5    2    4    3    4    4  ...    5    5    3
# 1     442    4    2    4    5    2    4    3    4    5  ...    3    4    3
# 2     473    3    4    5    4    2    3    4    3    4  ...    4    3    3
# 3     478    4    3    4    4    2    5    3    1    4  ...    5    4    4
# 4     525    3    1    4    4    2    3    2    2    4  ...    3    3    4
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 103  2255    4    2    4    5    1    4    3    3    4  ...    5    4    4
# 104  2256    5    1    5    4    2    5    4    1    5  ...    4    4    5
# 105  2257    4    2    4    5    3    4    3    3    4  ...    5    4    5
# 106  2258    4    3    3    4    2    4    2    3    2  ...    5    5    3
# 107  2260    5    2    4    4    1    3    5    2    5  ...    2    2    4
#
#      Q55  Q56  Q57  Q58  Q59  Q60                         Type
# ...

# %%
df
# Out:
#        ID  Q01  Q02  Q03  Q04  Q05  Q06  Q07  Q08  Q09  ...  Q52  Q53  Q54  \
# 0     148    4    3    5    5    2    4    3    4    4  ...    5    5    3
# 1     442    4    2    4    5    2    4    3    4    5  ...    3    4    3
# 2     473    3    4    5    4    2    3    4    3    4  ...    4    3    3
# 3     478    4    3    4    4    2    5    3    1    4  ...    5    4    4
# 4     525    3    1    4    4    2    3    2    2    4  ...    3    3    4
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 103  2255    4    2    4    5    1    4    3    3    4  ...    5    4    4
# 104  2256    5    1    5    4    2    5    4    1    5  ...    4    4    5
# 105  2257    4    2    4    5    3    4    3    3    4  ...    5    4    5
# 106  2258    4    3    3    4    2    4    2    3    2  ...    5    5    3
# 107  2260    5    2    4    4    1    3    5    2    5  ...    2    2    4
#
#      Q55  Q56  Q57  Q58  Q59  Q60                         Type
# ...

# %%
type_counts = df['Type'].value_counts()

# Plot the histogram
plt.figure(figsize=(8, 6))
ax = type_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Students by Cluster Type')
plt.xlabel('Cluster Type')
plt.ylabel('Number of Students')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility

# Annotate each bar with its count
for i, count in enumerate(type_counts):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
class_mapping = {'Engaged Learners':1, 'Moderately Engaged Learners':2, 'Undecided Learners':3, 'Competitive Learners':4, 'Disengaged Learners':5}
df['gr_div'] = df['Type'].map(class_mapping)
df
# Out:
#        ID  Q01  Q02  Q03  Q04  Q05  Q06  Q07  Q08  Q09  ...  Q53  Q54  Q55  \
# 0     148    4    3    5    5    2    4    3    4    4  ...    5    3    4
# 1     442    4    2    4    5    2    4    3    4    5  ...    4    3    4
# 2     473    3    4    5    4    2    3    4    3    4  ...    3    3    4
# 3     478    4    3    4    4    2    5    3    1    4  ...    4    4    4
# 4     525    3    1    4    4    2    3    2    2    4  ...    3    4    5
# ..    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 103  2255    4    2    4    5    1    4    3    3    4  ...    4    4    4
# 104  2256    5    1    5    4    2    5    4    1    5  ...    4    5    4
# 105  2257    4    2    4    5    3    4    3    3    4  ...    4    5    5
# 106  2258    4    3    3    4    2    4    2    3    2  ...    5    3    4
# 107  2260    5    2    4    4    1    3    5    2    5  ...    2    4    5
#
#      Q56  Q57  Q58  Q59  Q60                         Type  gr_div
# ...

# %%
modified_df = df[['ID','gr_div']]
modified_df
# Out:
#        ID  gr_div
# 0     148       2
# 1     442       2
# 2     473       1
# 3     478       1
# 4     525       2
# ..    ...     ...
# 103  2255       1
# 104  2256       2
# 105  2257       2
# 106  2258       4
# 107  2260       2
#
# [108 rows x 2 columns]

# %%
modified_df.to_csv('../modified_data/gr.csv')
